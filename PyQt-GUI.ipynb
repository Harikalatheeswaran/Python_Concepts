# %% [markdown]
# ---

# %% [markdown]
# # <center> **_PyQt5 Arena !_**

# %% [markdown]
# ---

# %%
import sys
from PyQt5 import QApplication, QLabel, QPushButton, QVBoxLayout, QWidget

# Create the application instance
app = QApplication(sys.argv)

# Create the main window
window = QWidget()
window.setWindowTitle('Non-Class PyQt Example')
window.setGeometry(100, 100, 300, 200)

# Create widgets
label = QLabel('Hello PyQt', window)
button = QPushButton('Click me', window)

# Create layout
layout = QVBoxLayout()
layout.addWidget(label)
layout.addWidget(button)

# Set layout for the window
window.setLayout(layout)

# Define button click event
def buttonClicked():
    print('Button clicked!')

# Connect button click event to function
button.clicked.connect(buttonClicked)

# Show the window
window.show()

# # Run the application event loop
sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [2], line 2
#       1 import sys
# ----> 2 from PyQt5 import QApplication, QLabel, QPushButton, QVBoxLayout, QWidget
#       4 # Create the application instance
#       5 app = QApplication(sys.argv)
#
# ImportError: cannot import name 'QApplication' from 'PyQt5' (unknown location)
