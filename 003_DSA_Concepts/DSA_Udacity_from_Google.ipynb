# %% [markdown]
# # <center> *__DSA in python by Google__*
# <br> Offered by Udacity

# %% [markdown]
# ##### *__1. Linked List__*

# %%
# c0de for an single element in a LL
# An Element has some value associated with it(which could be anything—a number, a string, a character, et cetera).
# It has a variable that points to the next element in the linked list.# code from the test

"""The LinkedList code from before is provided below.
Add three functions to the LinkedList.
"get_position" returns the element at a certain position.
The "insert" function will add an element to a particular
spot in the list.
"delete" will delete the first element with that
particular value.
Then, use "Test Run" and "Submit" to run the test cases
at the bottom."""

class Element(object):
    def __init__(self, value):
        self.value = value
        self.next = None
        
class LinkedList(object):
    def __init__(self, head=None):
        self.head = head
        
    def append(self, new_element):
        """Appends a new element at the end of the linked list.
        """
        # Checking if there is a head element in the LL, if not then new node become the head of the LL.
        current = self.head
        if self.head:
            while current.next:
                current = current.next
            current.next = new_element
        else:
            self.head = new_element
            
    def get_position(self, position):
        """Get an element from a particular position.
        Assume the first position is "1".
        Return "None" if position is not in the list."""
        l = self.length()
        if position > l:
            return None
        else:
            current = self.head
            for _ in range(position):
                x  = current
                current = current.next
            return x
        
    def length(self):
        """Returns the length of the Linked List."""
        count = 0
        current  = self.head
        while current.next:
            count += 1
            current = current.next
        if current.next == None and current.value != None:
            count += 1
        return count
    
    def print_ll(self):
        """Prints the contents of the Linked List"""
        current  = self.head
        while current.next:
            print(current.value)
            current = current.next
        if current.next == None and current.value != None:
            print(current.value)
        
        
    def insert(self, new_element, position):
        """Insert a new node at the given position.
        Assume the first position is "1".
        Inserting at position 3 means between
        the 2nd and 3rd elements."""
    
        if position > self.length() or position < 1:
            return None
        else:
            if position == 1:
                current = self.head
                new_element.next = current
                self.head = new_element
            else:
                current = self.head
                for _ in range(position-2):
                    current = current.next
                new_element.next  = current.next
                current.next = new_element
    
    def delete(self, value):
        """Delete the first node with a given value."""
        current  = self.head
        l = self.length()
        if current.value == value:
            self.head = current.next
        else:
            for _ in range(l-1):
                if current.next.value == value:
                    x = current.next
                    current.next = x.next
                else:
                    current = current.next

# Test cases
# Set up some Elements
e1 = Element(11)
e2 = Element(22)
e3 = Element(33)
e4 = Element(44)

# Start setting up a LinkedList
ll = LinkedList(e1)
ll.append(e2)
ll.append(e3)
ll.append(e4)

print("Before Deletion:")
ll.print_ll()
print("\nAfter deletion :")
ll.delete(55)
ll.print_ll()

# %% [markdown]
# #### *__Stacks using Linked List :__*

# %%
# Implementation of stacks using Linked List

"""Add a couple methods to our LinkedList class,
and use that to implement a Stack.
You have 4 functions below to fill in:
insert_first, delete_first, push, and pop.
Think about this while you're implementing:
why is it easier to add an "insert_first"
function than just use "append"?"""

class Element(object):
    def __init__(self, value):
        self.value = value
        self.next = None
        
class LinkedList(object):
    def __init__(self, head=None):
        self.head = head
        
    def append(self, new_element):
        current = self.head
        if self.head:
            while current.next:
                current = current.next
            current.next = new_element
        else:
            self.head = new_element

    def insert_first(self, new_element):
        "Insert new element as the head of the LinkedList"
        current = self.head
        self.head = new_element
        self.head.next = current

    def delete_first(self):
        "Delete the first (head) element in the LinkedList as return it"
        current = self.head
        if self.head:
            self.head = current.next
            return current

class Stack(object):
    def __init__(self,top=None):
        self.ll = LinkedList(top)

    def push(self, new_element):
        "Push (add) a new element onto the top of the stack"
        self.ll.insert_first(new_element)
        
    def print_stack(self):
        """Prints the contents of the stack"""
        l = self.ll
        current  =l.head
        while current.next:
            print(current.value)
            current = current.next
        if current.next == None and current.value != None:
            print(current.value)
        

    def pop(self):
        "Pop (remove) the first element off the top of the stack and return it"
        x = self.ll.delete_first()
        return x
    
# Test cases
# Set up some Elements
e1 = Element(1)
e2 = Element(2)
e3 = Element(3)
e4 = Element(4)

# Start setting up a Stack
stack = Stack(e1)

# Test stack functionality
stack.push(e2)
stack.push(e3)
print(stack.pop().value)
print(stack.pop().value)
print(stack.pop().value)
print(stack.pop())
stack.push(e4)
print(stack.pop().value)

# %% [markdown]
# #### *__Queues__*
#
# * It can be done by doing the following:
# > 1. from collections import deque <br>
# > 2. import queue

# %% [markdown]
# #### *__Binary Search Algorithm__*

# %% [markdown]
# * In binary search, we perform the seaching operation on the sorted arrays.
# * It's kinda recursion. The list is divided based on the middle element and here's how it goes...
# * Let's say the search element is "n".
# * First, the middle element is found and compared to the search element n.
# * If the serch element is greater, the second half of the array is searched, and vice-versa...and the process is repeated till the search element is found by dividing the arrays based on the middle element.

# %%
# Binary search algorithm as per the 12th tetbook

def binary_search(input_array, value):
    m = 0
    index = -1
    l, u = 0, len(input_array)
    # lower bound = 0, upper bound = len

    while(l<=u):
        m = int((l+u)/2)
        if value == input_array[m]:
            index = m
            break
        else:
            if value < input_array[m]:
                u = m-1
            else:
                l = m+1
    
    if index >= 0:
        return index+1
    else:
        return -1
    
def linear_search(input_list, value):
    index = -1
    for i in range(0, len(input_list)):
        if input_list[i] == value:
            index = i
            break
    return index+1
    

#print(linear_search(test_list, test_val1))
print(binary_search([1,2,3,4,6,9], 9))

# %% [markdown]
# #### *__Fibbonacci numbers using recursion__*

# %%
"""
Fibbonacci series: 0,1,1,2,3,5,8...
"""

def fib(n):
    if n<= 0 :
        return 0
    if n == 1:
        return 1
    else:
        x = fib(n-1)+fib(n-2)
        return x
    
print(fib(4))

# %% [markdown]
# #### *__Sorting__*

# %% [markdown]
# 1. Bubble sort:
# * It is called bubble sort because, every itereation the largest element bubbles out at the end.
# * It is a in place sorting algorithm which does no create a copy and space complexity is O(1).
# * Insertion sort is much preferred when compared to bubble sort.
# * Best case effeiciency : O(n)  (just onne iteration)
# * Avg and worst case :  O(n^2)

# %%
# which runs one iteration of bubble sort, just to bubble up the last element.
# also can be used to find the largest element in the list.

def bubble_once(a):
    for i in range(0,len(a)-1):
        if a[i+1] < a[i]:
            a[i], a[i+1] = a[i+1], a[i]
    return a

x = [2,4,1,3,9,20,25,6,21,14]
for i in range(3):
    print(bubble_once(x))

# %% [markdown]
# 2. Merge sort
#
# * It uses the divide and conquer principe.
# * Avg and worst case efficiency : O(nlog(n))
# * If needed serch online.

# %% [markdown]
# 3. Quick sort
#
# * This is the most efficient sorting algorightm and is most widely used.
# * It in inplace sorting algorithm and hence the space complexity is O(1)
# * Here, an element is chosen as the pivot (usually the last element) and all the elements less than pivot are put to the left of the pivot and this process continues recursively.
# * Worst case : O(n^2)
# * Best Case : O(n log(n))

# %%
# Quick sort
import random
def quicksort(array):
    """Performs quick sort on the input array."""
    n = len(array)
    
    # Normal version
    
    def qs_pass(x, pivot):
        i = 0
        while pivot != i :
            if x[i] > x[pivot]:
                x.insert(pivot, x.pop(i))
                pivot = pivot - 1
            else:
                i+=1
    '''
    def qs_pass_rev(x, pivot):
        i = len(x)-1
        while pivot != i :
            if x[i] < x[pivot]:
                x.insert(pivot, x.pop(i))
                pivot = pivot + 1
            else:
                i-=1
    '''
    
    for i in range(2*n):
        pivot = i//2
        qs_pass(array, pivot)
        #qs_pass_rev(array, pivot)
        
    return array
    

test = [800, 21, 4, 100, 3,10,610,  9, 1000,-1,  20, 25, 6,603,  21, 14, 90, 98,0, 9]

print(quicksort(test))

# %%
x = [4, 2, 9, 1, 6, 3]


def qs_pass(x):
    pivot = len(x)-1
    i = 0
    while pivot != i :
        if x[i] > x[pivot]:
            x.insert(pivot, x.pop(i))
            pivot = pivot - 1
        else:
            i+=1
            
def qs_pass_rev(x, pivot):
    #pivot = 0
    i = len(x)-1
    while pivot != i :
        if x[i] < x[pivot]:
            x.insert(pivot, x.pop(i))
            pivot = pivot + 1
        else:
            i-=1

print(x)

# %% [markdown]
# #### *__Hashing & Hash Tables__*

# %% [markdown]
# In this quiz, you'll write your own hash table and hash function that uses string keys. Your table will store strings in buckets by their first two letters, according to the formula below:<br>
#
# >Hash Value = (ASCII Value of First Letter * 100) + ASCII Value of Second Letter <br>
#
# You can assume that the string will have at least two letters, and the first two characters are uppercase letters (ASCII values from 65 to 90). You can use the Python function ord() to get the ASCII value of a letter, and chr() to get the letter associated with an ASCII value.<br>
#
# You'll create a HashTable class, methods to store and lookup values, and a helper function to calculate a hash value given a string. You cannot use a Python dictionary—only lists! And remember to store lists at each bucket, and not just the string itself. For example, you can store "UDACITY" at index 8568 as ["UDACITY"].

# %%
"""Write a HashTable class that stores strings
in a hash table, where keys are calculated
using the first two letters of the string."""

class HashTable(object):
    def __init__(self):
        self.table = [None]*10000

    def store(self, string):
        """Input a string that's stored in 
        the table."""
        index = hash(string)
        if self.table[index] == None:
            self.table[index] = [string]
        else:
            self.table[index].append(string)

    def lookup(self, string):
        """Return the hash value if the
        string is already in the table.
        Return -1 otherwise."""
        index = hash(string)
        if self.table[index] :
            return index
        return -1
    
    def hash(string):
        if string[0] and string[1]:
            first,second = string[0], string[1]
            return abs((ord(first)*100 + ord(second)))
        return -1

    def calculate_hash_value(self, string):
        """Helper function to calulate a
        hash value from a string."""
        return hash(string)

# %%
# Setup
hash_table = HashTable()

# Test calculate_hash_value
# Should be 8568
print(hash_table.calculate_hash_value('UDACITY'))

# Test lookup edge case
# Should be -1
print(hash_table.lookup('UDACITY'))

# Test store
hash_table.store('UDACITY')
# Should be 8568
print(hash_table.lookup('UDACITY'))

# Test store edge case
hash_table.store('UDACIOUS')
# Should be 8568
print(hash_table.lookup('UDACIOUS'))
# Out:
# 8568
# -1
# 8568
# 8568
